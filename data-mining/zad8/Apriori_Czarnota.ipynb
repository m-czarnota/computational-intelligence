# %% [markdown]
# Celem laboratorium było wykonanie implementacji algorytmu Apriori oraz przetestowanie go na dwóch zbiorach danych.

# %% [markdown]
# Importy:

# %%
from __future__ import annotations
import time
import pandas as pd
import copy
from itertools import combinations_with_replacement

# %% [markdown]
# Pomocnicza klasa realizująca wypisywanie postępów na ekran oraz informująca o czasie wykonania danej funkcji:

# %%
class VerbosityHelper:
    def __init__(self, is_enabled: bool = True, verbosity_level: int = 1):
        self.is_enabled: bool = is_enabled
        self.verbosity_level: int = verbosity_level

    def verbose(self, callback: callable, params: list = [], required_level: int = 1, message: str = 'Time of execution'):
        if self.is_enabled is False or self.verbosity_level < required_level:
            return callback(*params)

        t1 = time.time()
        result = callback(*params)
        t2 = time.time()

        time_result = t2 - t1
        indents = ''.join(['\t' for _ in range(required_level)])
        print(f'{indents}{message} - {time_result:.4f}s')

        return result

# %% [markdown]
# Klasa algorytmu Apriori.
# Jedna publiczna metoda `generate_rules` odpowiada za generowanie reguł i wykorzystuje ona dwie pomocnicze chronione metody `_generate_candidates` oraz `_create_rules`.

# %%
class Apriori:
    def __init__(self, min_supp: float = 0.3, min_conf: float = 0.7, verbose: bool = True, verbosity_level: int = 1):
        self.min_supp: float = min_supp
        self.min_conf: float = min_conf

        self.frequents: list = []
        self.rules: pd.DataFrame = pd.DataFrame()

        self.__verbosity_helper = VerbosityHelper(verbose, verbosity_level)
        self.__dataset_length: int = 0

    def generate_rules(self, dataset: pd.DataFrame) -> pd.DataFrame:
        self.__dataset_length = dataset.shape[0]

        self.frequents = self.__verbosity_helper.verbose(self._generate_candidates, [dataset], message='Time of generating candidates')
        self.rules = self.__verbosity_helper.verbose(self._create_rules, message='Time of creating rules')

        return self.rules

    def _generate_candidates(self, dataset: pd.DataFrame) -> list:
        frequents: list = []
        f: dict = self.__verbosity_helper.verbose(self.__get_unique_items_from_dataset, [dataset], 2, 'Time of selecting uniques items from dataset')

        while len(f) != 0:
            frequents.append(copy.deepcopy(f))

            c = self.__generate_candidates_from_frequencies(f, dataset)
            c = self.__prune_candidates(c)

            f = copy.deepcopy(c)

        return frequents

    def _create_rules(self) -> pd.DataFrame:
        frequents_mapped = list(reversed([{key: set() for key in frequencies} for frequencies in self.frequents[1:]]))
        generated_rules = pd.DataFrame(columns=['rule', 'supp', 'conf', 'lift'])

        for frequencies in frequents_mapped:
            for keys in frequencies.keys():
                df = pd.DataFrame(columns=['rule', 'supp', 'conf', 'lift'])
                generated_rules = pd.concat([generated_rules, self.__generate_rules_helper(keys, df)],
                                            ignore_index=True)

        return generated_rules.sort_values(by=['lift'], ascending=False)

    @staticmethod
    def __get_unique_items_from_dataset(dataset: pd.DataFrame, with_counts: bool = True) -> dict | list:
        uniques = {}

        for transaction_iter, transaction_items in dataset.iterrows():
            for value in transaction_items:
                if value is None or pd.isnull(value):
                    continue

                if value in uniques.keys():
                    uniques[value] += 1
                else:
                    uniques[value] = 1

        if not with_counts:
            return list(uniques.keys())

        return uniques

    @staticmethod
    def __generate_candidates_from_frequencies(frequencies: dict, dataset: pd.DataFrame) -> dict:
        """
        Generates all combinations of items in transactions dataset and count them.

        Example:
             {'a': 5, 'b': 7, 'c': 7}, {('a', 'b'): 3, ('b', 'c'): 5}, {('a', 'b', 'c'): 2}
        """
        candidates = {}
        first_item = list(frequencies.keys())[0]

        if type(first_item) == str:  # for one element item set
            candidates = {tuple(sorted([a, b])): 0 for (a, b) in combinations_with_replacement(list(frequencies.keys()), 2) if a != b}
        else:  # for multi element item set
            for frequency_item1 in frequencies.keys():
                frequency_item1_set = set(frequency_item1)

                for frequency_item2 in frequencies.keys():
                    frequency_item2_set = set(frequency_item2)

                    if len(frequency_item1_set.intersection(frequency_item2_set)) == 0 or frequency_item1_set == frequency_item2_set:
                        continue

                    key = tuple(sorted({*frequency_item1_set, *frequency_item2_set}))
                    candidates[key] = 0

        for keys in candidates.keys():
            where_is_keys = dataset.isin(keys).sum(axis=1) >= len(keys)
            candidates[keys] = where_is_keys.sum()

        return candidates

    def __prune_candidates(self, candidates: dict) -> dict:
        pruned_candidates = {}

        for key, count in candidates.items():
            if count / self.__dataset_length >= self.min_supp:
                pruned_candidates[key] = count

        return pruned_candidates

    def __generate_rules_helper(self, keys: list, local_rules: pd.DataFrame, local_word: list = []) -> pd.DataFrame:
        if len(keys) == 1:
            return local_rules

        for key_iter, key in enumerate(keys):
            keys_copy = copy.deepcopy(list(keys))  # copy to prevent modify original looped keys

            removed = keys_copy.pop(key_iter)
            keys_copy_tuple = tuple(keys_copy)  # tuple, because list is unhashable type

            # resulting element: from {} => {} the word is the second pair of brackets
            word = copy.deepcopy(local_word)
            word.append(removed)
            word = list(sorted(word))
            word_tuple = tuple(word)  # tuple, because list is unhashable type

            # calculating conf for pruning
            supp_expression = self.__find_expression_count_in_frequents(tuple(keys)) / self.__dataset_length
            supp_resulting = self.__find_expression_count_in_frequents(tuple([*word])) / self.__dataset_length
            conf = supp_expression / supp_resulting

            # reverse pruning - add only when condition is meet
            if conf >= self.min_conf:
                supp_factors = self.__find_expression_count_in_frequents(keys_copy_tuple) / self.__dataset_length

                local_rule = pd.Series({
                    'rule': f'{keys_copy_tuple} => {word_tuple}',
                    'supp': {'expr': supp_expression, 'factors': supp_factors, 'resulting': supp_resulting},
                    'conf': conf})
                local_rules = pd.concat([local_rules, local_rule.to_frame().T], ignore_index=True)

            generated_rules = self.__generate_rules_helper(keys_copy, local_rules, word)
            generated_rules = generated_rules.sort_values(by=['conf'], ascending=False).drop_duplicates(subset=['rule'])
            local_rules = pd.concat([local_rules, generated_rules], ignore_index=True)

        # removing duplicated rules and calc lift for rules
        local_rules = local_rules.sort_values(by=['conf'], ascending=False).drop_duplicates(subset=['rule'])
        local_rules['lift'] = self.__calc_lift_for_rules(local_rules)

        return local_rules

    def __find_expression_count_in_frequents(self, expression: tuple) -> int:
        expression = tuple(sorted(expression))
        expression = expression[0] if len(expression) == 1 else expression
        index_to_search = len(expression) - 1 if type(expression) != str else 0

        return self.frequents[index_to_search][expression]

    @staticmethod
    def __calc_lift_for_rules(local_rules: pd.DataFrame) -> list:
        lifts = []

        for rule_iter, rule in local_rules.iterrows():
            supp = rule['supp']

            lift = supp['expr'] / (supp['factors'] * supp['resulting'])
            lifts.append(lift)

        return lifts

# %% [markdown]
# Wykonanie algorytmu dla zbioru z punktu pierwszego instrukcji laboratoryjnej:

# %%
dataset = pd.DataFrame.from_dict({
        "t1": {'a', 'b', 'c'},
        "t2": {'b', 'c', 'd'},
        't3': {'a', 'b', 'd', 'e'},
        't4': {'a', 'c', 'd', 'e'},
        't5': {'b', 'c', 'd', 'e'},
        't6': {'b', 'd', 'c'},
        't7': {'c', 'd'},
        't8': {'a', 'b', 'c'},
        't9': {'a', 'd', 'e'},
        't10': {'b', 'd'},
    }, orient='index')

min_supp = 0.3
min_conf = 0.7

apriori = Apriori(min_supp, min_conf, verbose=True, verbosity_level=1)
print(apriori.generate_rules(dataset).to_markdown())
# Out:
# 	Time of generating candidates - 0.0060s
# 	Time of creating rules - 0.0562s
# |    | rule                 | supp                                            |     conf |     lift |
# |---:|:---------------------|:------------------------------------------------|---------:|---------:|
# |  3 | ('e',) => ('a', 'd') | {'expr': 0.4, 'factors': 0.4, 'resulting': 0.3} | 1.33333  | 3.33333  |
# |  6 | ('a', 'd') => ('e',) | {'expr': 0.3, 'factors': 0.3, 'resulting': 0.4} | 0.75     | 2.5      |
# |  4 | ('d',) => ('a', 'e') | {'expr': 0.4, 'factors': 0.8, 'resulting': 0.3} | 1.33333  | 1.66667  |
# |  5 | ('a',) => ('d', 'e') | {'expr': 0.3, 'factors': 0.5, 'resulting': 0.4} | 0.75     | 1.5      |
# | 11 | ('a',) => ('e',)     | {'expr': 0.3, 'factors': 0.5, 'resulting': 0.4} | 0.75     | 1.5      |
# |  1 | ('c',) => ('b', 'd') | {'expr': 0.5, 'factors': 0.7, 'resulting': 0.5} | 1        | 1.42857  |
# |  2 | ('b',) => ('c', 'd') | {'expr': 0.5, 'factors': 0.7, 'resulting': 0.5} | 1        | 1.42857  |
# |  0 | ('d',) => ('b', 'c') | {'expr': 0.5, 'factors': 0.8, 'resulting': 0.5} | 1        | 1.25     |
# | 12 | ('d',) => ('e',)     | {'expr': 0.4, 'factors': 0.8, 'resulting': 0.4} | 1        | 1.25     |
# |  7 | ('c',) => ('b',)     | {'expr': 0.5, 'factors': 0.7, 'resulting': 0.7} | 0.714286 | 1.02041  |
# |  8 | ('b',) => ('c',)     | {'expr': 0.5, 'factors': 0.7, 'resulting': 0.7} | 0.714286 | 1.02041  |
# |  9 | ('d',) => ('c',)     | {'expr': 0.5, 'factors': 0.8, 'resulting': 0.7} | 0.714286 | 0.892857 |
# | 10 | ('d',) => ('b',)     | {'expr': 0.5, 'factors': 0.8, 'resulting': 0.7} | 0.714286 | 0.892857 |

# %% [markdown]
# Wykonanie algorytmu dla zbioru 'Store_data.csv':

# %%
store = pd.read_csv('Store_data.csv')

min_supp = 0.005
min_conf = 1.5

apriori = Apriori(min_supp, min_conf, verbose=True, verbosity_level=2)
print(apriori.generate_rules(store).to_markdown())
# Out:
# 		Time of selecting uniques items from dataset - 0.1850s
# 	Time of generating candidates - 104.2419s
# 	Time of creating rules - 2.3391s
# |     | rule                                                        | supp                                                                                              |    conf |     lift |
# |----:|:------------------------------------------------------------|:--------------------------------------------------------------------------------------------------|--------:|---------:|
# | 240 | ('ground beef',) => ('herb & pepper', 'spaghetti')          | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.016266666666666665}               | 2.40984 | 24.5234  |
# | 189 | ('ground beef',) => ('herb & pepper', 'mineral water')      | {'expr': 0.040933333333333335, 'factors': 0.09826666666666667, 'resulting': 0.017066666666666667} | 2.39844 | 24.4074  |
# |   1 | ('spaghetti',) => ('chocolate', 'milk', 'mineral water')    | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.014133333333333333}  | 4.22642 | 24.2711  |
# | 238 | ('ground beef',) => ('grated cheese', 'spaghetti')          | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.016533333333333334}               | 2.37097 | 24.1279  |
# | 187 | ('ground beef',) => ('grated cheese', 'mineral water')      | {'expr': 0.040933333333333335, 'factors': 0.09826666666666667, 'resulting': 0.017466666666666665} | 2.34351 | 23.8485  |
# |   3 | ('milk',) => ('chocolate', 'mineral water', 'spaghetti')    | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.015866666666666668}                             | 3.02521 | 23.3427  |
# |   0 | ('mineral water',) => ('chocolate', 'milk', 'spaghetti')    | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.011066666666666667}  | 5.39759 | 22.6536  |
# | 124 | ('mineral water',) => ('chocolate', 'soup')                 | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.010266666666666667}  | 5.12987 | 21.53    |
# |   2 | ('chocolate',) => ('milk', 'mineral water', 'spaghetti')    | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.015733333333333332}                | 3.34746 | 20.4113  |
# | 141 | ('spaghetti',) => ('mineral water', 'salmon')               | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.016933333333333335}  | 3.52756 | 20.2578  |
# | 157 | ('spaghetti',) => ('herb & pepper', 'mineral water')        | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.017066666666666667}  | 3.5     | 20.0995  |
# | 237 | ('spaghetti',) => ('grated cheese', 'ground beef')          | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.011333333333333334}               | 3.45882 | 19.8631  |
# | 152 | ('spaghetti',) => ('grated cheese', 'mineral water')        | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.017466666666666665}  | 3.41985 | 19.6392  |
# | 221 | ('spaghetti',) => ('ground beef', 'shrimp')                 | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.011466666666666667}               | 3.4186  | 19.6321  |
# |  73 | ('milk',) => ('mineral water', 'turkey')                    | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.0192}                                           | 2.5     | 19.2901  |
# | 232 | ('spaghetti',) => ('ground beef', 'tomatoes')               | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.011733333333333333}               | 3.34091 | 19.1859  |
# | 233 | ('ground beef',) => ('spaghetti', 'tomatoes')               | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.020933333333333335}               | 1.87261 | 19.0564  |
# | 222 | ('ground beef',) => ('shrimp', 'spaghetti')                 | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.0212}                             | 1.84906 | 18.8167  |
# | 177 | ('chocolate',) => ('escalope', 'mineral water')             | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.017066666666666667}                | 3.08594 | 18.8167  |
# |  27 | ('spaghetti',) => ('burgers', 'ground beef')                | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.012}                              | 3.26667 | 18.7596  |
# | 120 | ('mineral water',) => ('frozen vegetables', 'soup')         | {'expr': 0.03573333333333333, 'factors': 0.23826666666666665, 'resulting': 0.008}                 | 4.46667 | 18.7465  |
# | 140 | ('mineral water',) => ('salmon', 'spaghetti')               | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.013466666666666667}  | 4.43564 | 18.6163  |
# |  28 | ('ground beef',) => ('burgers', 'spaghetti')                | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.021466666666666665}               | 1.82609 | 18.583   |
# |  77 | ('milk',) => ('mineral water', 'whole wheat rice')          | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.020133333333333333}                             | 2.38411 | 18.3959  |
# |  95 | ('milk',) => ('frozen smoothie', 'mineral water')           | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.020133333333333333}                             | 2.38411 | 18.3959  |
# |  41 | ('mineral water',) => ('cooking oil', 'eggs')               | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.011733333333333333}  | 4.34091 | 18.2187  |
# | 127 | ('ground beef',) => ('mineral water', 'soup')               | {'expr': 0.040933333333333335, 'factors': 0.09826666666666667, 'resulting': 0.023066666666666666} | 1.77457 | 18.0587  |
# |  75 | ('spaghetti',) => ('mineral water', 'turkey')               | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.0192}                | 3.11111 | 17.8663  |
# |  57 | ('mineral water',) => ('eggs', 'olive oil')                 | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.012}                 | 4.24444 | 17.8138  |
# |  72 | ('mineral water',) => ('milk', 'turkey')                    | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.011333333333333334}                | 4.23529 | 17.7754  |
# | 167 | ('ground beef',) => ('mineral water', 'shrimp')             | {'expr': 0.040933333333333335, 'factors': 0.09826666666666667, 'resulting': 0.023466666666666667} | 1.74432 | 17.7509  |
# | 100 | ('mineral water',) => ('spaghetti', 'whole wheat rice')     | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.014133333333333333}  | 4.22642 | 17.7382  |
# | 126 | ('mineral water',) => ('ground beef', 'soup')               | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.009733333333333333} | 4.20548 | 17.6503  |
# | 122 | ('mineral water',) => ('soup', 'spaghetti')                 | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.014266666666666667}  | 4.18692 | 17.5724  |
# | 199 | ('milk',) => ('frozen smoothie', 'spaghetti')               | {'expr': 0.03546666666666667, 'factors': 0.1296, 'resulting': 0.0156}                             | 2.2735  | 17.5425  |
# |  67 | ('spaghetti',) => ('eggs', 'olive oil')                     | {'expr': 0.036533333333333334, 'factors': 0.17413333333333333, 'resulting': 0.012}                | 3.04444 | 17.4834  |
# |  48 | ('mineral water',) => ('eggs', 'tomatoes')                  | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.012266666666666667}  | 4.15217 | 17.4266  |
# | 242 | ('ground beef',) => ('olive oil', 'spaghetti')              | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.022933333333333333}               | 1.7093  | 17.3945  |
# |  19 | ('ground beef',) => ('burgers', 'mineral water')            | {'expr': 0.040933333333333335, 'factors': 0.09826666666666667, 'resulting': 0.0244}               | 1.6776  | 17.0719  |
# | 184 | ('ground beef',) => ('mineral water', 'tomatoes')           | {'expr': 0.040933333333333335, 'factors': 0.09826666666666667, 'resulting': 0.0244}               | 1.6776  | 17.0719  |
# |  53 | ('mineral water',) => ('eggs', 'herb & pepper')             | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.012533333333333334}  | 4.06383 | 17.0558  |
# | 155 | ('spaghetti',) => ('frozen smoothie', 'mineral water')      | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.020133333333333333}  | 2.96689 | 17.038   |
# | 139 | ('spaghetti',) => ('cooking oil', 'mineral water')          | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.020133333333333333}  | 2.96689 | 17.038   |
# | 101 | ('spaghetti',) => ('mineral water', 'whole wheat rice')     | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.020133333333333333}  | 2.96689 | 17.038   |
# |  76 | ('mineral water',) => ('milk', 'whole wheat rice')          | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.011866666666666666}                | 4.04494 | 16.9765  |
# |  54 | ('eggs',) => ('herb & pepper', 'mineral water')             | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.017066666666666667}  | 2.98437 | 16.6045  |
# | 108 | ('mineral water',) => ('low fat yogurt', 'spaghetti')       | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0152}                | 3.92982 | 16.4934  |
# | 228 | ('spaghetti',) => ('cake', 'chocolate')                     | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.013733333333333334}               | 2.85437 | 16.3919  |
# | 121 | ('frozen vegetables',) => ('mineral water', 'soup')         | {'expr': 0.03573333333333333, 'factors': 0.09533333333333334, 'resulting': 0.023066666666666666}  | 1.54913 | 16.2496  |
# |  89 | ('milk',) => ('chicken', 'mineral water')                   | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.0228}                                           | 2.10526 | 16.2443  |
# | 209 | ('spaghetti',) => ('french fries', 'ground beef')           | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.013866666666666666}               | 2.82692 | 16.2342  |
# | 179 | ('mineral water',) => ('cake', 'chocolate')                 | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.013733333333333334}  | 3.83495 | 16.0952  |
# | 162 | ('mineral water',) => ('chocolate', 'cooking oil')          | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.013733333333333334}  | 3.83495 | 16.0952  |
# | 154 | ('mineral water',) => ('frozen smoothie', 'spaghetti')      | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0156}                | 3.82906 | 16.0705  |
# |  82 | ('milk',) => ('mineral water', 'soup')                      | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.023066666666666666}                             | 2.08092 | 16.0565  |
# | 132 | ('frozen vegetables',) => ('mineral water', 'shrimp')       | {'expr': 0.03573333333333333, 'factors': 0.09533333333333334, 'resulting': 0.023466666666666667}  | 1.52273 | 15.9727  |
# | 163 | ('chocolate',) => ('cooking oil', 'mineral water')          | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.020133333333333333}                | 2.61589 | 15.9506  |
# | 176 | ('chocolate',) => ('frozen smoothie', 'mineral water')      | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.020133333333333333}                | 2.61589 | 15.9506  |
# | 223 | ('spaghetti',) => ('chocolate', 'tomatoes')                 | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.014133333333333333}               | 2.77358 | 15.9279  |
# | 241 | ('spaghetti',) => ('ground beef', 'olive oil')              | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.014133333333333333}               | 2.77358 | 15.9279  |
# | 194 | ('milk',) => ('chicken', 'spaghetti')                       | {'expr': 0.03546666666666667, 'factors': 0.1296, 'resulting': 0.0172}                             | 2.06202 | 15.9106  |
# | 235 | ('ground beef',) => ('pancakes', 'spaghetti')               | {'expr': 0.0392, 'factors': 0.09826666666666667, 'resulting': 0.0252}                             | 1.55556 | 15.8299  |
# | 138 | ('mineral water',) => ('cooking oil', 'spaghetti')          | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.015866666666666668}  | 3.76471 | 15.8004  |
# |  86 | ('milk',) => ('mineral water', 'shrimp')                    | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.023466666666666667}                             | 2.04545 | 15.7828  |
# | 170 | ('mineral water',) => ('chocolate', 'tomatoes')             | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.014133333333333333}  | 3.72642 | 15.6397  |
# | 234 | ('spaghetti',) => ('ground beef', 'pancakes')               | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.014533333333333334}               | 2.69725 | 15.4896  |
# | 156 | ('mineral water',) => ('herb & pepper', 'spaghetti')        | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.016266666666666665}  | 3.67213 | 15.4119  |
# | 207 | ('spaghetti',) => ('green tea', 'ground beef')              | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.0148}                             | 2.64865 | 15.2105  |
# |  12 | ('milk',) => ('burgers', 'mineral water')                   | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.0244}                                           | 1.96721 | 15.1791  |
# |  91 | ('milk',) => ('mineral water', 'tomatoes')                  | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.0244}                                           | 1.96721 | 15.1791  |
# | 151 | ('mineral water',) => ('grated cheese', 'spaghetti')        | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.016533333333333334}  | 3.6129  | 15.1633  |
# |  74 | ('mineral water',) => ('spaghetti', 'turkey')               | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.016533333333333334}  | 3.6129  | 15.1633  |
# | 186 | ('mineral water',) => ('grated cheese', 'ground beef')      | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.011333333333333334} | 3.61176 | 15.1585  |
# |  43 | ('mineral water',) => ('eggs', 'shrimp')                    | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.014133333333333333}  | 3.60377 | 15.125   |
# |  96 | ('mineral water',) => ('cake', 'milk')                      | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.013333333333333334}                | 3.6     | 15.1091  |
# | 168 | ('mineral water',) => ('chicken', 'chocolate')              | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.014666666666666666}  | 3.59091 | 15.071   |
# | 204 | ('milk',) => ('chocolate', 'olive oil')                     | {'expr': 0.032266666666666666, 'factors': 0.1296, 'resulting': 0.016533333333333334}              | 1.95161 | 15.0587  |
# | 146 | ('spaghetti',) => ('chicken', 'mineral water')              | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.0228}                | 2.61988 | 15.0453  |
# | 166 | ('mineral water',) => ('ground beef', 'shrimp')             | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.011466666666666667} | 3.56977 | 14.9822  |
# | 123 | ('spaghetti',) => ('mineral water', 'soup')                 | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.023066666666666666}  | 2.5896  | 14.8713  |
# |  46 | ('mineral water',) => ('chicken', 'eggs')                   | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0144}                | 3.53704 | 14.8449  |
# | 110 | ('mineral water',) => ('chocolate', 'low fat yogurt')       | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.014933333333333333}  | 3.52679 | 14.8018  |
# | 175 | ('mineral water',) => ('chocolate', 'frozen smoothie')      | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.014933333333333333}  | 3.52679 | 14.8018  |
# |  29 | ('eggs',) => ('mineral water', 'turkey')                    | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.0192}                | 2.65278 | 14.7595  |
# | 183 | ('mineral water',) => ('ground beef', 'tomatoes')           | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.011733333333333333} | 3.48864 | 14.6417  |
# | 143 | ('spaghetti',) => ('mineral water', 'shrimp')               | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.023466666666666667}  | 2.54545 | 14.6178  |
# | 145 | ('mineral water',) => ('chicken', 'spaghetti')              | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0172}                | 3.47287 | 14.5756  |
# | 195 | ('spaghetti',) => ('milk', 'tomatoes')                      | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.014}                 | 2.53333 | 14.5482  |
# |  22 | ('milk',) => ('burgers', 'chocolate')                       | {'expr': 0.032266666666666666, 'factors': 0.1296, 'resulting': 0.0172}                            | 1.87597 | 14.4751  |
# |  90 | ('mineral water',) => ('milk', 'tomatoes')                  | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.014}                               | 3.42857 | 14.3896  |
# | 109 | ('spaghetti',) => ('low fat yogurt', 'mineral water')       | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.023866666666666668}  | 2.50279 | 14.3729  |
# |  18 | ('mineral water',) => ('burgers', 'ground beef')            | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.012}                | 3.41111 | 14.3164  |
# | 198 | ('spaghetti',) => ('frozen smoothie', 'milk')               | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.014266666666666667}  | 2.48598 | 14.2763  |
# |  94 | ('mineral water',) => ('frozen smoothie', 'milk')           | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.014266666666666667}                | 3.36449 | 14.1207  |
# | 218 | ('spaghetti',) => ('frozen vegetables', 'olive oil')        | {'expr': 0.027866666666666668, 'factors': 0.17413333333333333, 'resulting': 0.011333333333333334} | 2.45882 | 14.1203  |
# | 169 | ('chocolate',) => ('chicken', 'mineral water')              | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.0228}                              | 2.30994 | 14.085   |
# |  42 | ('eggs',) => ('cooking oil', 'mineral water')               | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.020133333333333333}  | 2.5298  | 14.0753  |
# | 239 | ('spaghetti',) => ('ground beef', 'herb & pepper')          | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.016}                              | 2.45    | 14.0697  |
# |  15 | ('spaghetti',) => ('burgers', 'mineral water')              | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.0244}                | 2.44809 | 14.0587  |
# | 148 | ('spaghetti',) => ('mineral water', 'tomatoes')             | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.0244}                | 2.44809 | 14.0587  |
# | 125 | ('chocolate',) => ('mineral water', 'soup')                 | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.023066666666666666}                | 2.28324 | 13.9222  |
# | 158 | ('mineral water',) => ('cake', 'spaghetti')                 | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.018133333333333335}  | 3.29412 | 13.8253  |
# | 193 | ('spaghetti',) => ('chicken', 'milk')                       | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.0148}                | 2.3964  | 13.7618  |
# | 203 | ('milk',) => ('chocolate', 'shrimp')                        | {'expr': 0.032266666666666666, 'factors': 0.1296, 'resulting': 0.018133333333333335}              | 1.77941 | 13.73    |
# | 165 | ('chocolate',) => ('mineral water', 'shrimp')               | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.023466666666666667}                | 2.24432 | 13.6849  |
# | 230 | ('spaghetti',) => ('chocolate', 'olive oil')                | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.016533333333333334}               | 2.37097 | 13.6158  |
# |  88 | ('mineral water',) => ('chicken', 'milk')                   | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.0148}                              | 3.24324 | 13.6118  |
# |  99 | ('milk',) => ('mineral water', 'olive oil')                 | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.027466666666666667}                             | 1.74757 | 13.4844  |
# |  97 | ('milk',) => ('cake', 'mineral water')                      | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.027466666666666667}                             | 1.74757 | 13.4844  |
# | 111 | ('chocolate',) => ('low fat yogurt', 'mineral water')       | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.023866666666666668}                | 2.2067  | 13.4555  |
# | 236 | ('spaghetti',) => ('olive oil', 'pancakes')                 | {'expr': 0.0252, 'factors': 0.17413333333333333, 'resulting': 0.0108}                             | 2.33333 | 13.3997  |
# | 181 | ('mineral water',) => ('chocolate', 'olive oil')            | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.016533333333333334}  | 3.18548 | 13.3694  |
# | 217 | ('spaghetti',) => ('frozen vegetables', 'ground beef')      | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.016933333333333335}               | 2.31496 | 13.2942  |
# |  81 | ('mineral water',) => ('milk', 'soup')                      | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.0152}                              | 3.15789 | 13.2536  |
# | 137 | ('mineral water',) => ('frozen vegetables', 'olive oil')    | {'expr': 0.03573333333333333, 'factors': 0.23826666666666665, 'resulting': 0.011333333333333334}  | 3.15294 | 13.2328  |
# | 229 | ('chocolate',) => ('cake', 'spaghetti')                     | {'expr': 0.0392, 'factors': 0.164, 'resulting': 0.018133333333333335}                             | 2.16176 | 13.1815  |
# | 171 | ('chocolate',) => ('mineral water', 'tomatoes')             | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.0244}                              | 2.15847 | 13.1614  |
# |  17 | ('chocolate',) => ('burgers', 'mineral water')              | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.0244}                              | 2.15847 | 13.1614  |
# |  25 | ('spaghetti',) => ('burgers', 'chocolate')                  | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.0172}                             | 2.27907 | 13.0881  |
# | 196 | ('milk',) => ('spaghetti', 'tomatoes')                      | {'expr': 0.03546666666666667, 'factors': 0.1296, 'resulting': 0.020933333333333335}               | 1.69427 | 13.0731  |
# | 128 | ('mineral water',) => ('olive oil', 'soup')                 | {'expr': 0.027466666666666667, 'factors': 0.23826666666666665, 'resulting': 0.008933333333333333} | 3.07463 | 12.9041  |
# |  16 | ('mineral water',) => ('burgers', 'chocolate')              | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.0172}                | 3.06202 | 12.8512  |
# | 212 | ('chocolate',) => ('escalope', 'french fries')              | {'expr': 0.03453333333333333, 'factors': 0.164, 'resulting': 0.0164}                              | 2.10569 | 12.8396  |
# |  21 | ('milk',) => ('burgers', 'spaghetti')                       | {'expr': 0.03546666666666667, 'factors': 0.1296, 'resulting': 0.021466666666666665}               | 1.65217 | 12.7483  |
# |  36 | ('mineral water',) => ('eggs', 'low fat yogurt')            | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0168}                | 3.03175 | 12.7242  |
# | 159 | ('spaghetti',) => ('cake', 'mineral water')                 | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.027466666666666667}  | 2.17476 | 12.489   |
# | 161 | ('spaghetti',) => ('mineral water', 'olive oil')            | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.027466666666666667}  | 2.17476 | 12.489   |
# | 178 | ('mineral water',) => ('chocolate', 'escalope')             | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.017733333333333334}  | 2.96992 | 12.4647  |
# |  47 | ('eggs',) => ('chicken', 'mineral water')                   | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.0228}                | 2.23392 | 12.4291  |
# | 219 | ('spaghetti',) => ('chocolate', 'shrimp')                   | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.018133333333333335}               | 2.16176 | 12.4144  |
# | 118 | ('mineral water',) => ('french fries', 'ground beef')       | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.013866666666666666} | 2.95192 | 12.3892  |
# |  31 | ('eggs',) => ('spaghetti', 'turkey')                        | {'expr': 0.036533333333333334, 'factors': 0.17973333333333333, 'resulting': 0.016533333333333334} | 2.20968 | 12.2942  |
# | 164 | ('mineral water',) => ('chocolate', 'shrimp')               | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.018133333333333335}  | 2.90441 | 12.1898  |
# |  92 | ('mineral water',) => ('milk', 'pancakes')                  | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.016533333333333334}                | 2.90323 | 12.1848  |
# | 190 | ('mineral water',) => ('ground beef', 'olive oil')          | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.014133333333333333} | 2.89623 | 12.1554  |
# |  44 | ('eggs',) => ('mineral water', 'shrimp')                    | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.023466666666666667}  | 2.17045 | 12.076   |
# | 147 | ('mineral water',) => ('spaghetti', 'tomatoes')             | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.020933333333333335}  | 2.8535  | 11.9761  |
# |  79 | ('milk',) => ('green tea', 'mineral water')                 | {'expr': 0.048, 'factors': 0.1296, 'resulting': 0.030933333333333334}                             | 1.55172 | 11.9732  |
# | 200 | ('spaghetti',) => ('milk', 'olive oil')                     | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.017066666666666667}  | 2.07812 | 11.9341  |
# | 201 | ('milk',) => ('olive oil', 'spaghetti')                     | {'expr': 0.03546666666666667, 'factors': 0.1296, 'resulting': 0.022933333333333333}               | 1.54651 | 11.933   |
# |  60 | ('milk',) => ('eggs', 'ground beef')                        | {'expr': 0.0308, 'factors': 0.1296, 'resulting': 0.02}                                            | 1.54    | 11.8827  |
# |  37 | ('eggs',) => ('low fat yogurt', 'mineral water')            | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.023866666666666668}  | 2.13408 | 11.8736  |
# | 142 | ('mineral water',) => ('shrimp', 'spaghetti')               | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0212}                | 2.81761 | 11.8254  |
# | 185 | ('mineral water',) => ('ground beef', 'pancakes')           | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.014533333333333334} | 2.81651 | 11.8208  |
# |  98 | ('mineral water',) => ('milk', 'olive oil')                 | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.017066666666666667}                | 2.8125  | 11.804   |
# | 180 | ('chocolate',) => ('cake', 'mineral water')                 | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.027466666666666667}                | 1.91748 | 11.6919  |
# | 182 | ('chocolate',) => ('mineral water', 'olive oil')            | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.027466666666666667}                | 1.91748 | 11.6919  |
# |  14 | ('mineral water',) => ('burgers', 'spaghetti')              | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.021466666666666665}  | 2.78261 | 11.6785  |
# |   4 | ('eggs',) => ('burgers', 'mineral water')                   | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.0244}                | 2.08743 | 11.614   |
# |  49 | ('eggs',) => ('mineral water', 'tomatoes')                  | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.0244}                | 2.08743 | 11.614   |
# | 107 | ('mineral water',) => ('green tea', 'ground beef')          | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.0148}               | 2.76577 | 11.6079  |
# | 191 | ('spaghetti',) => ('green tea', 'milk')                     | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.0176}                | 2.01515 | 11.5725  |
# | 205 | ('chocolate',) => ('milk', 'olive oil')                     | {'expr': 0.032266666666666666, 'factors': 0.164, 'resulting': 0.017066666666666667}               | 1.89062 | 11.5282  |
# |  78 | ('mineral water',) => ('green tea', 'milk')                 | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.0176}                              | 2.72727 | 11.4463  |
# |  85 | ('mineral water',) => ('milk', 'shrimp')                    | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.0176}                              | 2.72727 | 11.4463  |
# | 224 | ('chocolate',) => ('spaghetti', 'tomatoes')                 | {'expr': 0.0392, 'factors': 0.164, 'resulting': 0.020933333333333335}                             | 1.87261 | 11.4184  |
# |  20 | ('spaghetti',) => ('burgers', 'milk')                       | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.017866666666666666}  | 1.98507 | 11.3997  |
# | 213 | ('french fries',) => ('chocolate', 'escalope')              | {'expr': 0.03453333333333333, 'factors': 0.17093333333333333, 'resulting': 0.017733333333333334}  | 1.94737 | 11.3926  |
# |  11 | ('mineral water',) => ('burgers', 'milk')                   | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.017866666666666666}                | 2.68657 | 11.2755  |
# | 220 | ('chocolate',) => ('shrimp', 'spaghetti')                   | {'expr': 0.0392, 'factors': 0.164, 'resulting': 0.0212}                                           | 1.84906 | 11.2747  |
# | 225 | ('spaghetti',) => ('chocolate', 'pancakes')                 | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.02}                               | 1.96    | 11.2557  |
# |  66 | ('spaghetti',) => ('eggs', 'ground beef')                   | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.02}                               | 1.96    | 11.2557  |
# |  55 | ('mineral water',) => ('cake', 'eggs')                      | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.019066666666666666}  | 2.67133 | 11.2115  |
# | 202 | ('chocolate',) => ('milk', 'shrimp')                        | {'expr': 0.032266666666666666, 'factors': 0.164, 'resulting': 0.0176}                             | 1.83333 | 11.1789  |
# | 135 | ('mineral water',) => ('frozen vegetables', 'pancakes')     | {'expr': 0.03573333333333333, 'factors': 0.23826666666666665, 'resulting': 0.013466666666666667}  | 2.65347 | 11.1365  |
# |  26 | ('chocolate',) => ('burgers', 'spaghetti')                  | {'expr': 0.0392, 'factors': 0.164, 'resulting': 0.021466666666666665}                             | 1.82609 | 11.1347  |
# | 103 | ('spaghetti',) => ('green tea', 'mineral water')            | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.030933333333333334}  | 1.93103 | 11.0894  |
# | 172 | ('mineral water',) => ('chocolate', 'pancakes')             | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.02}                  | 2.63333 | 11.052   |
# | 208 | ('chocolate',) => ('french fries', 'frozen vegetables')     | {'expr': 0.03453333333333333, 'factors': 0.164, 'resulting': 0.019066666666666666}                | 1.81119 | 11.0438  |
# |  23 | ('chocolate',) => ('burgers', 'milk')                       | {'expr': 0.032266666666666666, 'factors': 0.164, 'resulting': 0.017866666666666666}               | 1.80597 | 11.012   |
# |  30 | ('mineral water',) => ('eggs', 'turkey')                    | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.019466666666666667}  | 2.61644 | 10.9811  |
# | 160 | ('mineral water',) => ('olive oil', 'spaghetti')            | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.022933333333333333}  | 2.60465 | 10.9317  |
# |  10 | ('eggs',) => ('burgers', 'chocolate')                       | {'expr': 0.03333333333333333, 'factors': 0.17973333333333333, 'resulting': 0.0172}                | 1.93798 | 10.7826  |
# |  32 | ('spaghetti',) => ('eggs', 'turkey')                        | {'expr': 0.036533333333333334, 'factors': 0.17413333333333333, 'resulting': 0.019466666666666667} | 1.87671 | 10.7774  |
# | 188 | ('mineral water',) => ('ground beef', 'herb & pepper')      | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.016}                | 2.55833 | 10.7373  |
# |  52 | ('mineral water',) => ('eggs', 'ground beef')               | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.02}                  | 2.54667 | 10.6883  |
# |  61 | ('eggs',) => ('french fries', 'frozen vegetables')          | {'expr': 0.0364, 'factors': 0.17973333333333333, 'resulting': 0.019066666666666666}               | 1.90909 | 10.6218  |
# | 211 | ('chocolate',) => ('french fries', 'pancakes')              | {'expr': 0.03453333333333333, 'factors': 0.164, 'resulting': 0.020133333333333333}                | 1.71523 | 10.4587  |
# | 231 | ('chocolate',) => ('olive oil', 'spaghetti')                | {'expr': 0.0392, 'factors': 0.164, 'resulting': 0.022933333333333333}                             | 1.7093  | 10.4226  |
# | 105 | ('chocolate',) => ('green tea', 'mineral water')            | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.030933333333333334}                | 1.70259 | 10.3816  |
# |  58 | ('eggs',) => ('mineral water', 'olive oil')                 | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.027466666666666667}  | 1.85437 | 10.3173  |
# |  56 | ('eggs',) => ('cake', 'mineral water')                      | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.027466666666666667}  | 1.85437 | 10.3173  |
# | 197 | ('spaghetti',) => ('ground beef', 'milk')                   | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.022}                              | 1.78182 | 10.2325  |
# | 150 | ('spaghetti',) => ('mineral water', 'pancakes')             | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.03373333333333333}   | 1.77075 | 10.1689  |
# | 114 | ('spaghetti',) => ('french fries', 'mineral water')         | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.03373333333333333}   | 1.77075 | 10.1689  |
# |  71 | ('chocolate',) => ('eggs', 'ground beef')                   | {'expr': 0.03333333333333333, 'factors': 0.164, 'resulting': 0.02}                                | 1.66667 | 10.1626  |
# | 136 | ('mineral water',) => ('frozen vegetables', 'ground beef')  | {'expr': 0.040933333333333335, 'factors': 0.23826666666666665, 'resulting': 0.016933333333333335} | 2.41732 | 10.1455  |
# | 210 | ('french fries',) => ('chocolate', 'pancakes')              | {'expr': 0.03453333333333333, 'factors': 0.17093333333333333, 'resulting': 0.02}                  | 1.72667 | 10.1014  |
# | 149 | ('mineral water',) => ('pancakes', 'spaghetti')             | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0252}                | 2.37037 |  9.94839 |
# | 216 | ('spaghetti',) => ('frozen vegetables', 'tomatoes')         | {'expr': 0.027866666666666668, 'factors': 0.17413333333333333, 'resulting': 0.016133333333333333} | 1.72727 |  9.91925 |
# |  50 | ('mineral water',) => ('eggs', 'pancakes')                  | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.021733333333333334}  | 2.34356 |  9.83586 |
# |  39 | ('mineral water',) => ('eggs', 'frozen vegetables')         | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.021733333333333334}  | 2.34356 |  9.83586 |
# |  62 | ('french fries',) => ('eggs', 'frozen vegetables')          | {'expr': 0.0364, 'factors': 0.17093333333333333, 'resulting': 0.021733333333333334}               | 1.67485 |  9.79824 |
# | 215 | ('spaghetti',) => ('chocolate', 'frozen vegetables')        | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.023066666666666666}               | 1.69942 |  9.75931 |
# | 227 | ('spaghetti',) => ('chocolate', 'ground beef')              | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.023066666666666666}               | 1.69942 |  9.75931 |
# |  63 | ('spaghetti',) => ('eggs', 'frozen vegetables')             | {'expr': 0.036533333333333334, 'factors': 0.17413333333333333, 'resulting': 0.021733333333333334} | 1.68098 |  9.65342 |
# |  65 | ('spaghetti',) => ('eggs', 'pancakes')                      | {'expr': 0.036533333333333334, 'factors': 0.17413333333333333, 'resulting': 0.021733333333333334} | 1.68098 |  9.65342 |
# | 214 | ('spaghetti',) => ('frozen vegetables', 'shrimp')           | {'expr': 0.027866666666666668, 'factors': 0.17413333333333333, 'resulting': 0.016666666666666666} | 1.672   |  9.60184 |
# | 130 | ('spaghetti',) => ('frozen vegetables', 'mineral water')    | {'expr': 0.05973333333333333, 'factors': 0.17413333333333333, 'resulting': 0.03573333333333333}   | 1.67164 |  9.59978 |
# |   6 | ('eggs',) => ('burgers', 'milk')                            | {'expr': 0.0308, 'factors': 0.17973333333333333, 'resulting': 0.017866666666666666}               | 1.72388 |  9.59132 |
# | 174 | ('mineral water',) => ('chocolate', 'ground beef')          | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.023066666666666666}  | 2.28324 |  9.5827  |
# | 133 | ('mineral water',) => ('chocolate', 'frozen vegetables')    | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.023066666666666666}  | 2.28324 |  9.5827  |
# |  24 | ('french fries',) => ('burgers', 'green tea')               | {'expr': 0.028533333333333334, 'factors': 0.17093333333333333, 'resulting': 0.017466666666666665} | 1.63359 |  9.55687 |
# | 206 | ('spaghetti',) => ('chocolate', 'green tea')                | {'expr': 0.0392, 'factors': 0.17413333333333333, 'resulting': 0.0236}                             | 1.66102 |  9.53877 |
# | 115 | ('chocolate',) => ('french fries', 'mineral water')         | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.03373333333333333}                 | 1.56126 |  9.51991 |
# | 173 | ('chocolate',) => ('mineral water', 'pancakes')             | {'expr': 0.05266666666666667, 'factors': 0.164, 'resulting': 0.03373333333333333}                 | 1.56126 |  9.51991 |
# | 226 | ('chocolate',) => ('pancakes', 'spaghetti')                 | {'expr': 0.0392, 'factors': 0.164, 'resulting': 0.0252}                                           | 1.55556 |  9.48509 |
# |   9 | ('eggs',) => ('burgers', 'spaghetti')                       | {'expr': 0.036533333333333334, 'factors': 0.17973333333333333, 'resulting': 0.021466666666666665} | 1.70186 |  9.46882 |
# | 102 | ('mineral water',) => ('green tea', 'spaghetti')            | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.026533333333333332}  | 2.25126 |  9.44847 |
# | 104 | ('mineral water',) => ('chocolate', 'green tea')            | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.0236}                | 2.23164 |  9.36614 |
# |  64 | ('chocolate',) => ('eggs', 'frozen vegetables')             | {'expr': 0.03333333333333333, 'factors': 0.164, 'resulting': 0.021733333333333334}                | 1.53374 |  9.35209 |
# |  70 | ('chocolate',) => ('eggs', 'pancakes')                      | {'expr': 0.03333333333333333, 'factors': 0.164, 'resulting': 0.021733333333333334}                | 1.53374 |  9.35209 |
# | 134 | ('mineral water',) => ('frozen vegetables', 'tomatoes')     | {'expr': 0.03573333333333333, 'factors': 0.23826666666666665, 'resulting': 0.016133333333333333}  | 2.21488 |  9.29579 |
# |  69 | ('eggs',) => ('chocolate', 'pancakes')                      | {'expr': 0.03333333333333333, 'factors': 0.17973333333333333, 'resulting': 0.02}                  | 1.66667 |  9.273   |
# |   8 | ('eggs',) => ('burgers', 'french fries')                    | {'expr': 0.0364, 'factors': 0.17973333333333333, 'resulting': 0.022}                              | 1.65455 |  9.20556 |
# |   7 | ('eggs',) => ('burgers', 'green tea')                       | {'expr': 0.0288, 'factors': 0.17973333333333333, 'resulting': 0.017466666666666665}               | 1.64885 |  9.1739  |
# |  35 | ('eggs',) => ('green tea', 'mineral water')                 | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.030933333333333334}  | 1.64655 |  9.16108 |
# |  93 | ('mineral water',) => ('ground beef', 'milk')               | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.022}                               | 2.18182 |  9.15704 |
# | 113 | ('mineral water',) => ('french fries', 'spaghetti')         | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0276}                | 2.16425 |  9.08332 |
# | 131 | ('mineral water',) => ('frozen vegetables', 'shrimp')       | {'expr': 0.03573333333333333, 'factors': 0.23826666666666665, 'resulting': 0.016666666666666666}  | 2.144   |  8.99832 |
# | 129 | ('mineral water',) => ('frozen vegetables', 'spaghetti')    | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.027866666666666668}  | 2.14354 |  8.99639 |
# |  68 | ('eggs',) => ('olive oil', 'spaghetti')                     | {'expr': 0.036533333333333334, 'factors': 0.17973333333333333, 'resulting': 0.022933333333333333} | 1.59302 |  8.86326 |
# | 106 | ('mineral water',) => ('green tea', 'pancakes')             | {'expr': 0.03373333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0164}                | 2.05691 |  8.63281 |
# | 192 | ('spaghetti',) => ('frozen vegetables', 'milk')             | {'expr': 0.03546666666666667, 'factors': 0.17413333333333333, 'resulting': 0.0236}                | 1.50282 |  8.63031 |
# |  83 | ('mineral water',) => ('frozen vegetables', 'milk')         | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.0236}                              | 2.0339  |  8.53623 |
# |  59 | ('eggs',) => ('french fries', 'milk')                       | {'expr': 0.0364, 'factors': 0.17973333333333333, 'resulting': 0.023733333333333332}               | 1.53371 |  8.53324 |
# |  80 | ('mineral water',) => ('french fries', 'milk')              | {'expr': 0.048, 'factors': 0.23826666666666665, 'resulting': 0.023733333333333332}                | 2.02247 |  8.48827 |
# |  51 | ('eggs',) => ('mineral water', 'pancakes')                  | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.03373333333333333}   | 1.50988 |  8.40068 |
# |  38 | ('eggs',) => ('french fries', 'mineral water')              | {'expr': 0.05093333333333333, 'factors': 0.17973333333333333, 'resulting': 0.03373333333333333}   | 1.50988 |  8.40068 |
# |  34 | ('mineral water',) => ('eggs', 'green tea')                 | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.025466666666666665}  | 2       |  8.39396 |
# | 119 | ('mineral water',) => ('cake', 'french fries')              | {'expr': 0.03373333333333333, 'factors': 0.23826666666666665, 'resulting': 0.017866666666666666}  | 1.88806 |  7.92415 |
# | 112 | ('mineral water',) => ('french fries', 'frozen vegetables') | {'expr': 0.03573333333333333, 'factors': 0.23826666666666665, 'resulting': 0.019066666666666666}  | 1.87413 |  7.86567 |
# |   5 | ('mineral water',) => ('burgers', 'eggs')                   | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0288}                | 1.76852 |  7.42243 |
# |  84 | ('mineral water',) => ('milk', 'spaghetti')                 | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.03546666666666667}   | 1.68421 |  7.06859 |
# | 117 | ('mineral water',) => ('french fries', 'pancakes')          | {'expr': 0.03373333333333333, 'factors': 0.23826666666666665, 'resulting': 0.020133333333333333}  | 1.6755  |  7.03202 |
# |  33 | ('mineral water',) => ('eggs', 'milk')                      | {'expr': 0.05093333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0308}                | 1.65368 |  6.94046 |
# |  40 | ('mineral water',) => ('eggs', 'spaghetti')                 | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.036533333333333334}  | 1.63504 |  6.86221 |
# |  87 | ('mineral water',) => ('chocolate', 'milk')                 | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.032266666666666666}  | 1.63223 |  6.85044 |
# |  45 | ('mineral water',) => ('chocolate', 'eggs')                 | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.03333333333333333}   | 1.58    |  6.63123 |
# |  13 | ('mineral water',) => ('burgers', 'french fries')           | {'expr': 0.03373333333333333, 'factors': 0.23826666666666665, 'resulting': 0.022}                 | 1.53333 |  6.43537 |
# | 116 | ('mineral water',) => ('chocolate', 'french fries')         | {'expr': 0.05266666666666667, 'factors': 0.23826666666666665, 'resulting': 0.03453333333333333}   | 1.5251  |  6.4008  |
# | 144 | ('mineral water',) => ('chocolate', 'spaghetti')            | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0392}                | 1.52381 |  6.3954  |
# | 153 | ('mineral water',) => ('ground beef', 'spaghetti')          | {'expr': 0.05973333333333333, 'factors': 0.23826666666666665, 'resulting': 0.0392}                | 1.52381 |  6.3954  |
